# %% [markdown]
# # Approach 2

# %%
import setup # sets up packages and environment in colab
# Out:
# Requirement already satisfied: anndata==0.11.4 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (0.11.4)
# Requirement already satisfied: array_api_compat==1.11.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (1.11.2)
# Requirement already satisfied: asttokens==3.0.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: clarabel==0.10.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (0.10.0)
# Requirement already satisfied: comm==0.2.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (0.2.2)
# Requirement already satisfied: contourpy==1.3.1 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: cvxpy==1.6.4 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (1.6.4)
# Requirement already satisfied: cycler==0.12.1 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: debugpy==1.8.13 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (1.8.13)
# Requirement already satisfied: decorator==5.2.1 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (5.2.1)
# Requirement already satisfied: exceptiongroup==1.2.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (1.2.2)
# Requirement already satisfied: executing==2.2.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (2.2.0)
# Requirement already satisfied: filelock==3.18.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (3.18.0)
# Requirement already satisfied: fonttools==4.57.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (4.57.0)
# Requirement already satisfied: fsspec==2025.3.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 15)) (2025.3.2)
# Requirement already satisfied: h5py==3.13.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 16)) (3.13.0)
# Requirement already satisfied: ipykernel==6.29.5 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 17)) (6.29.5)
# Requirement already satisfied: ipython==8.35.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 18)) (8.35.0)
# Requirement already satisfied: jedi==0.19.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 19)) (0.19.2)
# Requirement already satisfied: Jinja2==3.1.6 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 20)) (3.1.6)
# Requirement already satisfied: joblib==1.4.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 21)) (1.4.2)
# Requirement already satisfied: jupyter_client==8.6.3 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 22)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.7.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 23)) (5.7.2)
# Requirement already satisfied: kiwisolver==1.4.8 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 24)) (1.4.8)
# Requirement already satisfied: legacy-api-wrap==1.4.1 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 25)) (1.4.1)
# Requirement already satisfied: llvmlite==0.44.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 26)) (0.44.0)
# Requirement already satisfied: MarkupSafe==3.0.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 27)) (3.0.2)
# Requirement already satisfied: matplotlib==3.10.1 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 28)) (3.10.1)
# Requirement already satisfied: matplotlib-inline==0.1.7 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 29)) (0.1.7)
# Requirement already satisfied: mpmath==1.3.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 30)) (1.3.0)
# Requirement already satisfied: natsort==8.4.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 31)) (8.4.0)
# Requirement already satisfied: nest-asyncio==1.6.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 32)) (1.6.0)
# Requirement already satisfied: networkx==3.4.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 33)) (3.4.2)
# Requirement already satisfied: numba==0.61.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 34)) (0.61.2)
# Requirement already satisfied: numpy==2.2.4 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 35)) (2.2.4)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 36)) (12.4.5.8)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 37)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 38)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 39)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 40)) (9.1.0.70)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 41)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 42)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 43)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 44)) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 45)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 46)) (2.21.5)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 47)) (12.4.127)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 48)) (12.4.127)
# Requirement already satisfied: osqp==1.0.3 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 49)) (1.0.3)
# Requirement already satisfied: packaging==24.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 50)) (24.2)
# Requirement already satisfied: pandas==2.2.3 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 51)) (2.2.3)
# Requirement already satisfied: parso==0.8.4 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 52)) (0.8.4)
# Requirement already satisfied: patsy==1.0.1 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 53)) (1.0.1)
# Requirement already satisfied: pexpect==4.9.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 54)) (4.9.0)
# Requirement already satisfied: pillow==11.1.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 55)) (11.1.0)
# Requirement already satisfied: platformdirs==4.3.7 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 56)) (4.3.7)
# Requirement already satisfied: prompt_toolkit==3.0.50 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 57)) (3.0.50)
# Requirement already satisfied: psutil==7.0.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 58)) (7.0.0)
# Requirement already satisfied: ptyprocess==0.7.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 59)) (0.7.0)
# Requirement already satisfied: pure_eval==0.2.3 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 60)) (0.2.3)
# Requirement already satisfied: Pygments==2.19.1 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 61)) (2.19.1)
# Requirement already satisfied: pynndescent==0.5.13 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 62)) (0.5.13)
# Requirement already satisfied: pyparsing==3.2.3 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 63)) (3.2.3)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 64)) (2.9.0.post0)
# Requirement already satisfied: pytz==2025.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 65)) (2025.2)
# Requirement already satisfied: pyzmq==26.4.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 66)) (26.4.0)
# Requirement already satisfied: scanpy==1.11.1 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 67)) (1.11.1)
# Requirement already satisfied: scikit-learn==1.5.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 68)) (1.5.2)
# Requirement already satisfied: scipy==1.15.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 69)) (1.15.2)
# Requirement already satisfied: scs==3.2.7.post2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 70)) (3.2.7.post2)
# Requirement already satisfied: seaborn==0.13.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 71)) (0.13.2)
# Requirement already satisfied: session-info2==0.1.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 72)) (0.1.2)
# Requirement already satisfied: setuptools==80.1.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 73)) (80.1.0)
# Requirement already satisfied: six==1.17.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 74)) (1.17.0)
# Requirement already satisfied: stack-data==0.6.3 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 75)) (0.6.3)
# Requirement already satisfied: statsmodels==0.14.4 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 76)) (0.14.4)
# Requirement already satisfied: sympy==1.13.1 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 77)) (1.13.1)
# Requirement already satisfied: threadpoolctl==3.6.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 78)) (3.6.0)
# Requirement already satisfied: torch==2.6.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 79)) (2.6.0)
# Requirement already satisfied: tornado==6.4.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 80)) (6.4.2)
# Requirement already satisfied: tqdm==4.67.1 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 81)) (4.67.1)
# Requirement already satisfied: traitlets==5.14.3 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 82)) (5.14.3)
# Requirement already satisfied: triton==3.2.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 83)) (3.2.0)
# Requirement already satisfied: typing_extensions==4.13.1 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 84)) (4.13.1)
# Requirement already satisfied: tzdata==2025.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 85)) (2025.2)
# Requirement already satisfied: umap-learn==0.5.7 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 86)) (0.5.7)
# Requirement already satisfied: wcwidth==0.2.13 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 87)) (0.2.13)
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import scanpy as sc
import pandas as pd
import numpy as np
import numpy.typing as npt
from IPython.display import display

np.random.seed(42) # set seed to make reproducible outputs

# %%
adata = sc.read_h5ad("./data/subdom_processed.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 2671 × 13144
#     obs: 'n_genes_by_counts', 'total_counts', 'clusters', 'ct_num_exp_genes', 'ct_score', 'ct_pseudotime'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std', 'ct_gene_corr', 'ct_correlates'
#     uns: 'clusters_colors', 'clusters_sizes', 'ct_params', 'hvg', 'leiden', 'log1p', 'neighbors', 'paga', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'Ms', 'Mu', 'log_tpm', 'spliced', 'tpm', 'unspliced'
#     obsp: 'connectivities', 'distances'

# %%
df_grn = pd.read_csv("./data/transcription_factor_adjacency_matrix.csv", index_col="gene_ids")
df_grn = df_grn.transpose()
df_grn.head()
# Out:
# gene_ids   SUB2.g1  SUB2.g2  SUB2.g11  SUB2.g16  SUB2.g18  SUB2.g21  SUB2.g22  \
# SUB2.g8          0        0         0         0         0         0         0
# SUB2.g231        0        0         0         0         0         1         0
# SUB2.g755        0        0         1         0         0         0         0
# SUB2.g902        1        1         1         0         0         0         0
# SUB2.g924        0        0         1         0         0         0         0
#
# gene_ids   SUB2.g26  SUB2.g27  SUB2.g31  ...  SUB2.g12978  SUB2.g12979  \
# SUB2.g8           0         0         0  ...            0            0
# SUB2.g231         0         0         0  ...            0            0
# SUB2.g755         0         0         0  ...            0            0
# SUB2.g902         0         0         0  ...            0            0
# SUB2.g924         0         0         0  ...            0            0
#
# gene_ids   SUB2.g12980  SUB2.g13052  SUB2.g13056  SUB2.g13090  SUB2.g13093  \
# SUB2.g8              0            0            0            0            0
# SUB2.g231            0            0            1            1            0
# SUB2.g755            0            1            0            0            0
# SUB2.g902            1            1            1            0            0
# SUB2.g924            0            0            0            1            0
#
# gene_ids   SUB2.g13119  SUB2.g13123  SUB2.g13134
# SUB2.g8              0            0            0
# SUB2.g231            0            0            0
# SUB2.g755            0            0            0
# SUB2.g902            0            0            0
# SUB2.g924            1            1            1
#
# [5 rows x 5582 columns]

# %% [markdown]
# ## Approach 2.1 - Similarity between relative changes of means

# %%
def mmc(x: npt.ArrayLike, y: npt.ArrayLike) -> npt.ArrayLike:
    """
    Calculates the maximum mean change.
    """
    return (y - x)/(np.maximum(x, y))

def score_similarity_relative_change(x: npt.ArrayLike, y: npt.ArrayLike) -> npt.ArrayLike:
    correlation_direction = np.sign(x * y)
    change_absolute_value = mmc(np.abs(x), np.abs(y))
    similarity_magnitude = 1 - np.abs(change_absolute_value)
    return correlation_direction * similarity_magnitude

def calculate_mean_change_similarity_matrix(cluster_a: npt.ArrayLike, cluster_b: npt.ArrayLike):
    mean_cluster_a = np.mean(cluster_a, axis=1)
    mean_cluster_b = np.mean(cluster_b, axis=1)
    relative_changes = mmc(mean_cluster_a, mean_cluster_b)
    n = relative_changes.shape[0]
    x = np.tile(relative_changes, (n, 1))
    similarity_matrix = score_similarity_relative_change(x, x.T)
    return similarity_matrix

# %% [markdown]
# ## Approach 2.2 - Maximum mean difference discrepancy

# %%
FloatScalar = np.floating | float

# TODO: vectorize this to make it faster

def gaussian_kernel_scalar(x: FloatScalar, y: FloatScalar, sigma: FloatScalar = 1.) -> float:
    numerator = (x - y) ** 2
    denominator = 2 * sigma ** 2
    return np.exp(- numerator / denominator)

def mean_kernel(x: npt.ArrayLike, y: npt.ArrayLike) -> npt.ArrayLike:
    n = x.shape[0]
    m = y.shape[0]

    sum_ = 0.
    for i in range(n):
        for j in range(m):
            sum_ += gaussian_kernel_scalar(x[i], y[j])
    return 1. / (n * m) * sum_

def calculate_mmdd_matrix(cluster_a: npt.ArrayLike, cluster_b: npt.ArrayLike):
    """
    Maximum mean difference discrepancy
    """
    num_genes = cluster_a.shape[1]
    similarity_matrix = np.zeros((num_genes, num_genes))
    for i in range(num_genes):
        for j in range(num_genes):
            x_a = cluster_a[:, i]
            x_b = cluster_b[:, i]
            y_a = cluster_a[:, j]
            y_b = cluster_b[:, j]

            similarity_matrix[i][j] = \
                + mean_kernel(x_a, x_a) - 2*mean_kernel(x_a, x_b) + mean_kernel(x_b, x_b) \
                + mean_kernel(y_a, y_a) - 2*mean_kernel(y_a, y_b) + mean_kernel(y_b, y_b) \
                + 2*mean_kernel(x_b, y_b) - 2*mean_kernel(x_a, y_a) \
                + 2*mean_kernel(x_b, y_a) - 2*mean_kernel(x_a, y_b)
            
    
def calculate_mmdd_similarity_matrix(cluster_a: npt.ArrayLike, cluster_b: npt.ArrayLike):
    mmdd_matrix = calculate_mmdd_matrix(cluster_a, cluster_b)

    mean_cluster_a = np.mean(cluster_a, axis=1)
    mean_cluster_b = np.mean(cluster_b, axis=1)
    relative_changes = mmc(mean_cluster_a, mean_cluster_b)
    correlation_directions = np.sign(relative_changes @ relative_changes.T)

    C = 1 # The gaussian kernel has an upper bound C of 1
    normalization_factor = 1 / (8 // 2 * C)
    return correlation_directions * (1 - normalization_factor * mmdd_matrix)
